# %% [markdown]
# #### Importing all necessary libraries.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
raw = pd.read_csv("C:/Users/zsbor/final_project_IronHack/data/WDIData_raw.csv")
raw
# Out:
#                        Country Name Country Code  \
# 0       Africa Eastern and Southern          AFE
# 1       Africa Eastern and Southern          AFE
# 2       Africa Eastern and Southern          AFE
# 3       Africa Eastern and Southern          AFE
# 4       Africa Eastern and Southern          AFE
# ...                             ...          ...
# 384365                     Zimbabwe          ZWE
# 384366                     Zimbabwe          ZWE
# 384367                     Zimbabwe          ZWE
# 384368                     Zimbabwe          ZWE
# 384369                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 0       Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# ...

# %%
# I standardized the column names
raw.columns = [column.lower().replace(' ', '_') for column in raw.columns]
raw
# Out:
#                        country_name country_code  \
# 0       Africa Eastern and Southern          AFE
# 1       Africa Eastern and Southern          AFE
# 2       Africa Eastern and Southern          AFE
# 3       Africa Eastern and Southern          AFE
# 4       Africa Eastern and Southern          AFE
# ...                             ...          ...
# 384365                     Zimbabwe          ZWE
# 384366                     Zimbabwe          ZWE
# 384367                     Zimbabwe          ZWE
# 384368                     Zimbabwe          ZWE
# 384369                     Zimbabwe          ZWE
#
#                                            indicator_name     indicator_code  \
# 0       Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# ...

# %%
# Check type of file
type(raw)
# Out:
# pandas.core.frame.DataFrame

# %%
# Number of rows and columns
raw.shape
# Out:
# (384370, 67)

# %%
# More detailed informtion about the dataframe : number of rows and columns, the total memory usage, 
# the data type of each column, and the number of non-NaN elements
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384370 entries, 0 to 384369
# Data columns (total 67 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country_name    384370 non-null  object
#  1   country_code    384370 non-null  object
#  2   indicator_name  384370 non-null  object
#  3   indicator_code  384370 non-null  object
#  4   1960            36961 non-null   float64
#  5   1961            41895 non-null   float64
#  6   1962            44138 non-null   float64
#  7   1963            43978 non-null   float64
#  8   1964            44496 non-null   float64
#  9   1965            46678 non-null   float64
#  10  1966            46705 non-null   float64
#  11  1967            48473 non-null   float64
#  12  1968            48047 non-null   float64
#  13  1969            48840 non-null   float64
#  14  1970            67083 non-null   float64
#  15  1971            74178 non-null   float64
# ...

# %%
#The number of elements in the dataframe
raw.size
# Out:
# 25752790

# %%
# Check data types in each column
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(raw.dtypes)
# Out:
# country_name       object
# country_code       object
# indicator_name     object
# indicator_code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
# 1986              float64
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# ...

# %%
#Check how many missing values are in each column
raw.isna().sum()
# Out:
# country_name           0
# country_code           0
# indicator_name         0
# indicator_code         0
# 1960              347409
#                    ...
# 2018              177930
# 2019              197942
# 2020              248347
# 2021              374344
# unnamed:_66       384370
# Length: 67, dtype: int64

# %%
raw.country_name.unique()
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
# ...

# %%
countries = ['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Republic of Cyprus', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Sweden']

# %%
raw = raw[raw.country_name.isin(countries)]
raw
# Out:
#        country_name country_code  \
# 86700       Austria          AUT
# 86701       Austria          AUT
# 86702       Austria          AUT
# 86703       Austria          AUT
# 86704       Austria          AUT
# ...             ...          ...
# 342460       Sweden          SWE
# 342461       Sweden          SWE
# 342462       Sweden          SWE
# 342463       Sweden          SWE
# 342464       Sweden          SWE
#
#                                            indicator_name     indicator_code  \
# 86700   Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 86701   Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 86702   Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 86703             Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 86704   Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...                                                   ...                ...
# ...

# %%
list(raw)
# Out:
# ['country_name',
#  'country_code',
#  'indicator_name',
#  'indicator_code',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  'unnamed:_66']

# %%
raw.drop(['country_code', 'indicator_code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2021', 'unnamed:_66'], axis = 1, inplace=True)
raw
# Out:
# C:\Users\zsbor\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        country_name                                     indicator_name   2001  \
# 86700       Austria  Access to clean fuels and technologies for coo...  100.0
# 86701       Austria  Access to clean fuels and technologies for coo...  100.0
# 86702       Austria  Access to clean fuels and technologies for coo...  100.0
# 86703       Austria            Access to electricity (% of population)  100.0
# 86704       Austria  Access to electricity, rural (% of rural popul...  100.0
# ...             ...                                                ...    ...
# 342460       Sweden  Women who believe a husband is justified in be...    NaN
# ...

# %%
indicators = ['GDP (current US$)', 'Life expectancy at birth, female (years)', 'Life expectancy at birth, male (years)', 'Unemployment, female (% of female labor force) (modeled ILO estimate)', 'Unemployment, female (% of female labor force) (national estimate)', 'Unemployment, male (% of male labor force) (modeled ILO estimate)', 'Unemployment, male (% of male labor force) (national estimate)', 'Fixed broadband subscriptions (per 100 people)', 'Fixed telephone subscriptions (per 100 people)', 'Mobile cellular subscriptions (per 100 people)', 'Individuals using the Internet (% of population)', 'Population, total', 'Population, female', 'Population, male']

# %%
raw = raw[raw.indicator_name.isin(indicators)]
raw
# Out:
#        country_name                                     indicator_name  \
# 87146       Austria     Fixed broadband subscriptions (per 100 people)
# 87148       Austria     Fixed telephone subscriptions (per 100 people)
# 87167       Austria                                  GDP (current US$)
# 87317       Austria   Individuals using the Internet (% of population)
# 87395       Austria           Life expectancy at birth, female (years)
# ...             ...                                                ...
# 342082       Sweden                                  Population, total
# 342419       Sweden  Unemployment, female (% of female labor force)...
# 342420       Sweden  Unemployment, female (% of female labor force)...
# 342421       Sweden  Unemployment, male (% of male labor force) (mo...
# 342422       Sweden  Unemployment, male (% of male labor force) (na...
#
#                 2001          2002          2003          2004          2005  \
# ...

# %%
#Check how many missing values are in each column
raw.isna().sum()
# Out:
# country_name      0
# indicator_name    0
# 2001              4
# 2002              3
# 2003              1
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# dtype: int64

# %%
raw.to_csv('C:/Users/zsbor/final_project_IronHack/data/WDIData_cleaned.csv')
